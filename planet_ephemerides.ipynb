# %% [markdown]
# # Planet Ephemerides
# ## Reproducing Annual Values from the Astronomical Almanac
#
# L.N. Fletcher
#
# Based on IDL code provided by Data Reduction Manager (DRM) - B. Fisher & G. Orton.  Enormous thanks for the hints from Pat Fry.

# %%
import numpy as np
import matplotlib.pyplot as plt
import spiceypy as spice
import glob, re, os
import time


d2r=np.pi/180.
r2d=180./np.pi

# %% [markdown]
# ## Read SPICE Kernels and Set Archinal (2009) J2000 Values

# %%
kernel_path = '/Users/lnf2/Data/generic_kernels/'

def find_spice_kernels(kernel_path):
    pcks  = sorted(glob.glob(kernel_path+"pck/*.tpc"))
    spks1 = sorted(glob.glob(kernel_path+"spk/planets/*.bsp"))
    #spks1 = sorted(glob.glob(kernel_path+"spk/de*.bsp"))
    spks2 = sorted(glob.glob(kernel_path+"spk/satellites/*.bsp"))
    fks   = sorted(glob.glob(kernel_path+"fk/planets/*.tf"))
    lsks  = sorted(glob.glob(kernel_path+"lsk/naif*.tls"))


    kernels = [pcks[-1], spks1[-1], *spks2, lsks[-1]]
    #kernels = [*pcks, *spks1, *spks2, *lsks, *fks]
    
    for kernel in kernels:
        #print(kernel)
        spice.furnsh(kernel)

find_spice_kernels(kernel_path)

# %%
# Transcription of Values from Archinal (2009) technical note
# Also the same as those in kernel pck0010.tpc
# Celest Mech Dyn Astr (2011) 109:101–135
# DOI 10.1007/s10569-010-9320-4

# JUPITER
# ---------------

# Rotation rates of three jovian longitude systems
wt3=870.536 #642 Extra sigfig in Almanac 2001, also in 2006 IAU report, but not in pck0010.tpc
wt2=870.270
wt1=877.900

#a1= North Pole RA
#a1=268.05773 # DRM Value
a0=268.056595 # Archinal Value and pck0010.tpc
arate=-0.006499

#d1= North Pole Dec
#d1=64.49712 # DRM Value
d0=64.495303 # Archinal Value and pck0010.tpc
drate=0.002413

# Argument of prime meridian for 2000 January 1st 12:00 TDB
w0_3=284.95
w0_2=43.3
w0_1=67.1

# SATURN
# ---------------
sat_wt3=810.7939024 
sat_w0_3=38.90 # Argument of prime meridian for 2000 January 1st 12:00 TDB
sat_a0=40.589
sat_arate=-0.036
sat_d0=83.537
sat_drate=-0.004

# URANUS
# ---------------
ura_wt3= -501.1600928
ura_w0_3=203.81 # Argument of prime meridian for 2000 January 1st 12:00 TDB
ura_a0=257.311
ura_arate=0.0
ura_d0= -15.175
ura_drate=0.0

# NEPTUNE
# ---------------
nep_wt3=536.312849
N=357.85 #  + 52.316T (assume T=0)
nep_w0_3=253.18-0.48*np.sin(N*d2r) # Argument of prime meridian for 2000 January 1st 12:00 TDB
nep_a0=299.36
nep_arate=0.70*np.sin(N*d2r)
nep_d0=43.4
nep_drate=-0.51*np.cos(N*d2r)

# %% [markdown]
# ## Calculating Argument of Prime Meridian for Jupiter

# %%
# Note that the Archinal 2009 definitions are for 2000 Jan 1st 12:00 
# "Barycentric Dynamical Time (TDB)"

et1 = spice.str2et('2000-01-01TDB12:00')
nyrs=21

# Note that the Astronomical Almanac uses "TT" or "terrestrial time"
# which is the same as TDT "Terrestrial Dynamical Time"
for i in range(1980,2030,1):
    yr=i
    
    # Almanac gives positions at January 0, 0hr TT/TDT, which is the same as Dec 31T00:00
    dstring=str(yr)+'-12-31TDT00:00'
    #print(dstring)
    
    

    et2 = spice.str2et(dstring)
    days=(et2-et1)/(24.*60.*60.)

    [pos, ltime] = spice.spkpos( 'JUPITER', et2, 'J2000','NONE', 'EARTH')
    [r, ra, dec ] = spice.recrad(pos)
    dist = spice.vnorm( pos )
    delta = spice.convrt( dist, 'KM', 'AU' )
    a=ra*r2d
    d=dec*r2d

    utc=spice.et2datetime(et2)
    print('')
    print('JUPITER: ',yr+1,'January 0, 0h, TT - Ndays=','{0:8.2f}'.format(days))
    print(' Range (AU), RA, DEC: {0:8.6f}'.format(delta), '{0:8.6f}'.format(a), '{0:8.6f}'.format(d))

# Calculate the argument of prime meridian for a single day

    w1=w0_1 + days*wt1
    w2=w0_2 + days*wt2
    w3=w0_3 + days*wt3

    w1=np.mod(w1,360.)
    w2=np.mod(w2,360.)
    w3=np.mod(w3,360.)

    print(' Argument of PM 1/2/3: {:6.3f}'.format(w1),'{:6.3f}'.format(w2),'{:6.3f}'.format(w3))

    
    #From IDL code planetlcm.pro
    #Be=asind(-sind(d1)*sind(d)-cosd(d1)*cosd(d)*cosd(a1-a))  

    # Tcent is the interval in Julian centuries from J2000
    Tcent=days/36525.
    a1=a0+arate*Tcent
    d1=d0+drate*Tcent
    
    print(' N.Pole RA/DEC: {:6.3f}'.format(a1),'{:6.3f}'.format(d1))

    
    sd1=np.sin(d1*d2r)
    sd=np.sin(d*d2r)
    cd1=np.cos(d1*d2r)
    cd=np.cos(d*d2r)
    ca1a=np.cos((a1-a)*d2r)
    sa1a=np.sin((a1-a)*d2r)

    arg=(-sd1*sd - cd1*cd*ca1a)
    Be=np.arcsin(arg)

    print(" Sub-Earth Latitude (jovicentric):",'{:6.3f}'.format(Be*r2d))

    cBe=np.cos(Be)

    # Correction term for jovicentric longitude of sub-earth point
    # From IDL code planetlcm.pro
    #K=atan2d((-cosd(d1)*sind(d)+sind(d1)*cosd(d)*cosd(a1-a))/cosd(Be),(cosd(d)*sind(a1-a))/cosd(Be))

    arg1= (-cd1*sd+sd1*cd*ca1a)/cBe
    arg2= (cd*sa1a)/cBe

    #atan2d = double(atan(x1,x2)*57.2958), i.e.  the angle in degrees whose tangent is x2/x1.  

    K=np.arctan2(arg1,arg2)*r2d

    #print("Longitude Correction K:",K)

    # Argument of prime meridian at the time of observation andedated by light time.
    lcm3=w0_3+wt3*(days-.0057755*delta)-K
    lcm3=np.mod(lcm3,360.)

    lcm2=w0_2+wt2*(days-.0057755*delta)-K
    lcm2=np.mod(lcm2,360.)
    lcm1=w0_1+wt1*(days-.0057755*delta)-K
    lcm1=np.mod(lcm1,360.)    
    print(" Calculated LCMIII:",'{:6.3f}'.format(lcm3))
    print(" Calculated LCMII:",'{:6.3f}'.format(lcm2))
    print(" Calculated LCMI:",'{:6.3f}'.format(lcm1))
# Out:
# 1981 January 0, 0h, TT - Ndays= -6940.50
#  Range (AU), RA, DEC: 5.353012 189.428643 -2.647330
#  Argument of PM 1/2/3:  2.150 14.365 209.842
#  N.Pole RA/DEC: 268.058 64.495
#  Sub-Earth Latitude (jovicentric): -2.471
#  Calculated LCMIII: 171.518
#  Calculated LCMII: 336.050
#  Calculated LCMI: 323.599
#
# 1982 January 0, 0h, TT - Ndays= -6575.50
#  Range (AU), RA, DEC: 5.818318 214.265630 -12.477405
#  Argument of PM 1/2/3: 35.650 142.915 75.482
#  N.Pole RA/DEC: 268.058 64.495
#  Sub-Earth Latitude (jovicentric): -3.058
#  Calculated LCMIII:  8.316
#  Calculated LCMII: 75.758
#  Calculated LCMI: 328.236
#
# 1983 January 0, 0h, TT - Ndays= -6210.50
#  Range (AU), RA, DEC: 6.132344 239.277559 -19.602648
#  Argument of PM 1/2/3: 69.150 271.465 301.122
#  N.Pole RA/DEC: 268.058 64.495
#  Sub-Earth Latitude (jovicentric): -3.023
#  Calculated LCMIII: 207.302
#  Calculated LCMII: 177.654
#  Calculated LCMI: 335.069
#
# 1984 January 0, 0h, TT - Ndays= -5845.50
#  Range (AU), RA, DEC: 6.239514 265.566592 -23.054520
#  Argument of PM 1/2/3: 102.650 40.015 166.762
#  N.Pole RA/DEC: 268.058 64.495
#  Sub-Earth Latitude (jovicentric): -2.429
#  Calculated LCMIII: 47.685
#  Calculated LCMII: 280.948
#  Calculated LCMI: 343.308
#
# 1985 January 0, 0h, TT - Ndays= -5479.50
#  Range (AU), RA, DEC: 6.114769 293.221746 -21.978549
#  Argument of PM 1/2/3: 294.050 318.835 182.938
#  N.Pole RA/DEC: 268.058 64.495
#  Sub-Earth Latitude (jovicentric): -1.353
#  Calculated LCMIII: 38.964
#  Calculated LCMII: 174.871
#  Calculated LCMI: 149.816
#
# 1986 January 0, 0h, TT - Ndays= -5114.50
#  Range (AU), RA, DEC: 5.764558 320.941027 -16.124735
#  Argument of PM 1/2/3: 327.550 87.385 48.578
#  N.Pole RA/DEC: 268.058 64.495
#  Sub-Earth Latitude (jovicentric):  0.060
#  Calculated LCMIII: 239.595
#  Calculated LCMII: 278.411
#  Calculated LCMI: 158.322
#
# 1987 January 0, 0h, TT - Ndays= -4749.50
#  Range (AU), RA, DEC: 5.240747 349.013603 -6.034907
#  Argument of PM 1/2/3:  1.050 215.935 274.218
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  1.580
#  Calculated LCMIII: 78.613
#  Calculated LCMII: 20.338
#  Calculated LCMI: 165.222
#
# 1988 January 0, 0h, TT - Ndays= -4384.50
#  Range (AU), RA, DEC: 4.671967 19.282351 6.752552
#  Argument of PM 1/2/3: 34.550 344.485 139.858
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  2.790
#  Calculated LCMIII: 274.310
#  Calculated LCMII: 118.944
#  Calculated LCMI: 168.803
#
# 1989 January 0, 0h, TT - Ndays= -4018.50
#  Range (AU), RA, DEC: 4.265118 54.869974 18.595881
#  Argument of PM 1/2/3: 225.950 263.305 156.034
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  3.080
#  Calculated LCMIII: 255.892
#  Calculated LCMII:  3.170
#  Calculated LCMI: 325.627
#
# 1990 January 0, 0h, TT - Ndays= -3653.50
#  Range (AU), RA, DEC: 4.168941 95.968809 23.206433
#  Argument of PM 1/2/3: 259.450 31.855 21.674
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  2.083
#  Calculated LCMIII: 83.441
#  Calculated LCMII: 93.628
#  Calculated LCMI: 321.040
#
# 1991 January 0, 0h, TT - Ndays= -3288.50
#  Range (AU), RA, DEC: 4.429586 134.859547 17.790953
#  Argument of PM 1/2/3: 292.950 160.405 247.314
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  0.280
#  Calculated LCMIII: 271.084
#  Calculated LCMII: 184.182
#  Calculated LCMI: 316.532
#
# 1992 January 0, 0h, TT - Ndays= -2923.50
#  Range (AU), RA, DEC: 4.911025 166.397908 7.088302
#  Argument of PM 1/2/3: 326.450 288.955 112.954
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric): -1.434
#  Calculated LCMIII: 101.807
#  Calculated LCMII: 277.816
#  Calculated LCMI: 315.095
#
# 1993 January 0, 0h, TT - Ndays= -2557.50
#  Range (AU), RA, DEC: 5.424249 192.923411 -4.128625
#  Argument of PM 1/2/3: 157.850 207.775 129.130
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric): -2.591
#  Calculated LCMIII: 86.656
#  Calculated LCMII: 165.309
#  Calculated LCMI: 115.145
#
# 1994 January 0, 0h, TT - Ndays= -2192.50
#  Range (AU), RA, DEC: 5.873992 217.655446 -13.639549
#  Argument of PM 1/2/3: 191.350 336.325 354.770
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric): -3.089
#  Calculated LCMIII: 283.818
#  Calculated LCMII: 265.382
#  Calculated LCMI: 120.148
#
# 1995 January 0, 0h, TT - Ndays= -1827.50
#  Range (AU), RA, DEC: 6.161929 242.789075 -20.312748
#  Argument of PM 1/2/3: 224.850 104.875 220.410
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric): -2.973
#  Calculated LCMIII: 123.060
#  Calculated LCMII:  7.535
#  Calculated LCMI: 127.238
#
# 1996 January 0, 0h, TT - Ndays= -1462.50
#  Range (AU), RA, DEC: 6.236923 269.252877 -23.190804
#  Argument of PM 1/2/3: 258.350 233.425 86.050
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric): -2.309
#  Calculated LCMIII: 323.592
#  Calculated LCMII: 110.976
#  Calculated LCMI: 135.627
#
# 1997 January 0, 0h, TT - Ndays= -1096.50
#  Range (AU), RA, DEC: 6.079311 296.993190 -21.458404
#  Argument of PM 1/2/3: 89.750 152.245 102.226
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric): -1.177
#  Calculated LCMIII: 314.892
#  Calculated LCMII:  4.920
#  Calculated LCMI: 302.157
#
# 1998 January 0, 0h, TT - Ndays=  -731.50
#  Range (AU), RA, DEC: 5.699295 324.732622 -14.974694
#  Argument of PM 1/2/3: 123.250 280.795 327.866
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  0.269
#  Calculated LCMIII: 155.387
#  Calculated LCMII: 108.325
#  Calculated LCMI: 310.529
#
# 1999 January 0, 0h, TT - Ndays=  -366.50
#  Range (AU), RA, DEC: 5.158737 352.974602 -4.387383
#  Argument of PM 1/2/3: 156.750 49.345 193.506
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  1.777
#  Calculated LCMIII: 354.041
#  Calculated LCMII: 209.887
#  Calculated LCMI: 317.065
#
# 2000 January 0, 0h, TT - Ndays=    -1.50
#  Range (AU), RA, DEC: 4.597924 23.821002 8.568695
#  Argument of PM 1/2/3: 190.250 177.895 59.146
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  2.900
#  Calculated LCMIII: 189.114
#  Calculated LCMII: 307.870
#  Calculated LCMI: 320.022
#
# 2001 January 0, 0h, TT - Ndays=   364.50
#  Range (AU), RA, DEC: 4.228708 60.349922 19.817183
#  Argument of PM 1/2/3: 21.650 96.715 75.322
#  N.Pole RA/DEC: 268.057 64.495
#  Sub-Earth Latitude (jovicentric):  3.018
#  Calculated LCMIII: 170.038
#  Calculated LCMII: 191.438
#  Calculated LCMI: 116.187
#
# 2002 January 0, 0h, TT - Ndays=   729.50
#  Range (AU), RA, DEC: 4.187473 101.719042 23.001832
#  Argument of PM 1/2/3: 55.150 225.265 300.962
#  N.Pole RA/DEC: 268.056 64.495
#  Sub-Earth Latitude (jovicentric):  1.860
#  Calculated LCMIII: 357.344
#  Calculated LCMII: 281.653
#  Calculated LCMI: 111.354
#
# 2003 January 0, 0h, TT - Ndays=  1094.50
#  Range (AU), RA, DEC: 4.490728 139.626726 16.491937
#  Argument of PM 1/2/3: 88.650 353.815 166.602
#  N.Pole RA/DEC: 268.056 64.495
#  Sub-Earth Latitude (jovicentric):  0.023
#  Calculated LCMIII: 185.334
#  Calculated LCMII: 12.554
#  Calculated LCMI: 107.191
#
# 2004 January 0, 0h, TT - Ndays=  1459.50
#  Range (AU), RA, DEC: 4.988177 170.201009 5.528876
#  Argument of PM 1/2/3: 122.150 122.365 32.242
#  N.Pole RA/DEC: 268.056 64.495
#  Sub-Earth Latitude (jovicentric): -1.626
#  Calculated LCMIII: 16.621
#  Calculated LCMII: 106.752
#  Calculated LCMI: 106.317
#
# 2005 January 0, 0h, TT - Ndays=  1825.50
#  Range (AU), RA, DEC: 5.495052 196.283385 -5.533702
#  Argument of PM 1/2/3: 313.550 41.185 48.418
#  N.Pole RA/DEC: 268.056 64.495
#  Sub-Earth Latitude (jovicentric): -2.695
#  Calculated LCMIII:  1.954
#  Calculated LCMII: 354.729
#  Calculated LCMI: 266.852
#
# 2006 January 0, 0h, TT - Ndays=  2190.50
#  Range (AU), RA, DEC: 5.924406 220.951748 -14.715415
#  Argument of PM 1/2/3: 347.050 169.735 274.058
#  N.Pole RA/DEC: 268.056 64.495
#  Sub-Earth Latitude (jovicentric): -3.107
#  Calculated LCMIII: 199.475
#  Calculated LCMII: 95.161
#  Calculated LCMI: 272.215
#
# 2007 January 0, 0h, TT - Ndays=  2555.50
#  Range (AU), RA, DEC: 6.183265 246.243961 -20.937234
#  Argument of PM 1/2/3: 20.550 298.285 139.698
#  N.Pole RA/DEC: 268.056 64.495
#  Sub-Earth Latitude (jovicentric): -2.914
#  Calculated LCMIII: 38.943
#  Calculated LCMII: 197.540
#  Calculated LCMI: 279.532
#
# 2008 January 0, 0h, TT - Ndays=  2920.50
#  Range (AU), RA, DEC: 6.224695 272.917673 -23.240524
#  Argument of PM 1/2/3: 54.050 66.835  5.338
#  N.Pole RA/DEC: 268.056 64.495
#  Sub-Earth Latitude (jovicentric): -2.182
#  Calculated LCMIII: 239.572
#  Calculated LCMII: 301.079
#  Calculated LCMI: 288.019
#
# 2009 January 0, 0h, TT - Ndays=  3286.50
#  Range (AU), RA, DEC: 6.034115 300.780596 -20.845743
#  Argument of PM 1/2/3: 245.450 345.655 21.514
#  N.Pole RA/DEC: 268.056 64.496
#  Sub-Earth Latitude (jovicentric): -0.994
#  Calculated LCMIII: 230.825
#  Calculated LCMII: 194.975
#  Calculated LCMI: 94.505
#
# 2010 January 0, 0h, TT - Ndays=  3651.50
#  Range (AU), RA, DEC: 5.626074 328.593030 -13.724926
#  Argument of PM 1/2/3: 278.950 114.205 247.154
#  N.Pole RA/DEC: 268.056 64.496
#  Sub-Earth Latitude (jovicentric):  0.481
#  Calculated LCMIII: 71.105
#  Calculated LCMII: 298.165
#  Calculated LCMI: 102.662
#
# 2011 January 0, 0h, TT - Ndays=  4016.50
#  Range (AU), RA, DEC: 5.073574 357.076374 -2.650703
#  Argument of PM 1/2/3: 312.450 242.755 112.794
#  N.Pole RA/DEC: 268.056 64.496
#  Sub-Earth Latitude (jovicentric):  1.971
#  Calculated LCMIII: 269.311
#  Calculated LCMII: 39.280
#  Calculated LCMI: 108.751
#
# 2012 January 0, 0h, TT - Ndays=  4381.50
#  Range (AU), RA, DEC: 4.527805 28.578230 10.398037
#  Argument of PM 1/2/3: 345.950 11.305 338.434
#  N.Pole RA/DEC: 268.056 64.496
#  Sub-Earth Latitude (jovicentric):  2.992
#  Calculated LCMIII: 103.712
#  Calculated LCMII: 136.590
#  Calculated LCMI: 111.035
#
# 2013 January 0, 0h, TT - Ndays=  4747.50
#  Range (AU), RA, DEC: 4.201384 66.018102 20.888445
#  Argument of PM 1/2/3: 177.350 290.125 354.610
#  N.Pole RA/DEC: 268.056 64.496
#  Sub-Earth Latitude (jovicentric):  2.928
#  Calculated LCMIII: 84.036
#  Calculated LCMII: 19.557
#  Calculated LCMI: 266.597
#
# 2014 January 0, 0h, TT - Ndays=  5112.50
#  Range (AU), RA, DEC: 4.214022 107.424713 22.593261
#  Argument of PM 1/2/3: 210.850 58.675 220.250
#  N.Pole RA/DEC: 268.056 64.496
#  Sub-Earth Latitude (jovicentric):  1.621
#  Calculated LCMIII: 271.225
#  Calculated LCMII: 109.657
#  Calculated LCMI: 261.646
#
# 2015 January 0, 0h, TT - Ndays=  5477.50
#  Range (AU), RA, DEC: 4.554921 144.276925 15.103636
#  Argument of PM 1/2/3: 244.350 187.225 85.890
#  N.Pole RA/DEC: 268.056 64.496
#  Sub-Earth Latitude (jovicentric): -0.232
#  Calculated LCMIII: 99.621
#  Calculated LCMII: 200.963
#  Calculated LCMI: 257.887
#
# 2016 January 0, 0h, TT - Ndays=  5842.50
#  Range (AU), RA, DEC: 5.064121 173.976827 3.949741
#  Argument of PM 1/2/3: 277.850 315.775 311.530
#  N.Pole RA/DEC: 268.056 64.496
#  Sub-Earth Latitude (jovicentric): -1.812
#  Calculated LCMIII: 291.448
#  Calculated LCMII: 295.701
#  Calculated LCMI: 257.553
#
# 2017 January 0, 0h, TT - Ndays=  6208.50
#  Range (AU), RA, DEC: 5.562722 199.704440 -6.937129
#  Argument of PM 1/2/3: 109.250 234.595 327.706
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -2.790
#  Calculated LCMIII: 277.219
#  Calculated LCMII: 184.116
#  Calculated LCMI: 58.526
#
# 2018 January 0, 0h, TT - Ndays=  6573.50
#  Range (AU), RA, DEC: 5.971209 224.368809 -15.770347
#  Argument of PM 1/2/3: 142.750  3.145 193.346
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -3.115
#  Calculated LCMIII: 115.060
#  Calculated LCMII: 284.868
#  Calculated LCMI: 64.210
#
# 2019 January 0, 0h, TT - Ndays=  6938.50
#  Range (AU), RA, DEC: 6.201439 249.848554 -21.509758
#  Argument of PM 1/2/3: 176.250 131.695 58.986
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -2.843
#  Calculated LCMIII: 314.727
#  Calculated LCMII: 27.446
#  Calculated LCMI: 71.727
#
# 2020 January 0, 0h, TT - Ndays=  7303.50
#  Range (AU), RA, DEC: 6.210104 276.718892 -23.202767
#  Argument of PM 1/2/3: 209.750 260.245 284.626
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -2.043
#  Calculated LCMIII: 155.440
#  Calculated LCMII: 131.068
#  Calculated LCMI: 80.300
#
# 2021 January 0, 0h, TT - Ndays=  7669.50
#  Range (AU), RA, DEC: 5.988219 304.658058 -20.127104
#  Argument of PM 1/2/3: 41.150 179.065 300.802
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -0.801
#  Calculated LCMIII: 146.645
#  Calculated LCMII: 24.917
#  Calculated LCMI: 246.739
#
# 2022 January 0, 0h, TT - Ndays=  8034.50
#  Range (AU), RA, DEC: 5.555230 332.499934 -12.385716
#  Argument of PM 1/2/3: 74.650 307.615 166.442
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric):  0.697
#  Calculated LCMIII: 346.719
#  Calculated LCMII: 127.901
#  Calculated LCMI: 254.691
#
# 2023 January 0, 0h, TT - Ndays=  8399.50
#  Range (AU), RA, DEC: 4.994617 1.209614 -0.882886
#  Argument of PM 1/2/3: 108.150 76.165 32.082
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric):  2.155
#  Calculated LCMIII: 184.502
#  Calculated LCMII: 228.593
#  Calculated LCMI: 260.358
#
# 2024 January 0, 0h, TT - Ndays=  8764.50
#  Range (AU), RA, DEC: 4.466954 33.364314 12.146715
#  Argument of PM 1/2/3: 141.650 204.715 257.722
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric):  3.060
#  Calculated LCMIII: 18.290
#  Calculated LCMII: 325.289
#  Calculated LCMI: 262.028
#
# 2025 January 0, 0h, TT - Ndays=  9130.50
#  Range (AU), RA, DEC: 4.183118 71.622145 21.751471
#  Argument of PM 1/2/3: 333.050 123.535 273.898
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric):  2.815
#  Calculated LCMIII: 358.118
#  Calculated LCMII: 207.762
#  Calculated LCMI: 57.092
#
# 2026 January 0, 0h, TT - Ndays=  9495.50
#  Range (AU), RA, DEC: 4.245462 112.870445 22.011740
#  Argument of PM 1/2/3:  6.550 252.085 139.538
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric):  1.378
#  Calculated LCMIII: 185.287
#  Calculated LCMII: 297.840
#  Calculated LCMI: 52.118
#
# 2027 January 0, 0h, TT - Ndays=  9860.50
#  Range (AU), RA, DEC: 4.618342 148.686560 13.681170
#  Argument of PM 1/2/3: 40.050 20.635  5.178
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -0.476
#  Calculated LCMIII: 14.094
#  Calculated LCMII: 29.558
#  Calculated LCMI: 48.770
#
# 2028 January 0, 0h, TT - Ndays= 10225.50
#  Range (AU), RA, DEC: 5.135757 177.633618 2.398113
#  Argument of PM 1/2/3: 73.550 149.185 230.818
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -1.983
#  Calculated LCMIII: 206.410
#  Calculated LCMII: 124.784
#  Calculated LCMI: 48.923
#
# 2029 January 0, 0h, TT - Ndays= 10591.50
#  Range (AU), RA, DEC: 5.625086 203.098700 -8.297316
#  Argument of PM 1/2/3: 264.950 68.005 246.994
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -2.872
#  Calculated LCMIII: 192.560
#  Calculated LCMII: 13.580
#  Calculated LCMI: 210.277
#
# 2030 January 0, 0h, TT - Ndays= 10956.50
#  Range (AU), RA, DEC: 6.013314 227.815678 -16.770060
#  Argument of PM 1/2/3: 298.450 196.555 112.634
#  N.Pole RA/DEC: 268.055 64.496
#  Sub-Earth Latitude (jovicentric): -3.112
#  Calculated LCMIII: 30.674
#  Calculated LCMII: 114.604
#  Calculated LCMI: 216.234

# %% [markdown]
# ## Saturn Calculation

# %%
# Note that the Archinal 2009 definitions are for 2000 Jan 1st 12:00 
# "Barycentric Dynamical Time (TDB)"

et1 = spice.str2et('2000-01-01TDB12:00')
nyrs=21

# Note that the Astronomical Almanac uses "TT" or "terrestrial time"
# which is the same as TDT "Terrestrial Dynamical Time"
for i in range(1980,2030,1):
    yr=i
    
    # Almanac gives positions at January 0, 0hr TT/TDT, which is the same as Dec 31T00:00
    dstring=str(yr)+'-12-31TDT00:00'
    #print(dstring)
    
    

    et2 = spice.str2et(dstring)
    days=(et2-et1)/(24.*60.*60.)

    [pos, ltime] = spice.spkpos( 'SATURN', et2, 'J2000','NONE', 'EARTH')
    [r, ra, dec ] = spice.recrad(pos)
    dist = spice.vnorm( pos )
    delta = spice.convrt( dist, 'KM', 'AU' )
    a=ra*r2d
    d=dec*r2d

    utc=spice.et2datetime(et2)
    print('')
    print('SATURN:',yr+1,'January 0, 0h, TT - Ndays=','{0:8.2f}'.format(days))
    print(' Range (AU), RA, DEC: {0:8.6f}'.format(delta), '{0:8.6f}'.format(a), '{0:8.6f}'.format(d))

# Calculate the argument of prime meridian for a single day

    w3=sat_w0_3 + days*sat_wt3
    w3=np.mod(w3,360.)

    print(' Argument of PM 3: {:6.3f}'.format(w3))

    
    #From IDL code planetlcm.pro
    #Be=asind(-sind(d1)*sind(d)-cosd(d1)*cosd(d)*cosd(a1-a))  

    # Tcent is the interval in Julian centuries from J2000
    Tcent=days/36525.
    a1=sat_a0+sat_arate*Tcent
    d1=sat_d0+sat_drate*Tcent
    
    print(' N.Pole RA/DEC: {:6.3f}'.format(a1),'{:6.3f}'.format(d1))

    
    sd1=np.sin(d1*d2r)
    sd=np.sin(d*d2r)
    cd1=np.cos(d1*d2r)
    cd=np.cos(d*d2r)
    ca1a=np.cos((a1-a)*d2r)
    sa1a=np.sin((a1-a)*d2r)

    arg=(-sd1*sd - cd1*cd*ca1a)
    Be=np.arcsin(arg)

    print(" Sub-Earth Latitude (centric):",'{:6.3f}'.format(Be*r2d))

    cBe=np.cos(Be)

    # Correction term for jovicentric longitude of sub-earth point
    # From IDL code planetlcm.pro
    #K=atan2d((-cosd(d1)*sind(d)+sind(d1)*cosd(d)*cosd(a1-a))/cosd(Be),(cosd(d)*sind(a1-a))/cosd(Be))

    arg1= (-cd1*sd+sd1*cd*ca1a)/cBe
    arg2= (cd*sa1a)/cBe

    #atan2d = double(atan(x1,x2)*57.2958), i.e.  the angle in degrees whose tangent is x2/x1.  

    K=np.arctan2(arg1,arg2)*r2d

    #print("Longitude Correction K:",K)

    # Argument of prime meridian at the time of observation andedated by light time.
    lcm3=sat_w0_3+sat_wt3*(days-.0057755*delta)-K
    lcm3=np.mod(lcm3,360.)

     
    print(" Calculated LCMIII:",'{:6.3f}'.format(lcm3))
# Out:
# SATURN: 1981 January 0, 0h, TT - Ndays= -6940.50
#  Range (AU), RA, DEC: 9.479438 189.873572 -1.698522
#  Argument of PM 3: 243.820
#  N.Pole RA/DEC: 40.596 83.538
#  Sub-Earth Latitude (centric):  7.248
#  Calculated LCMIII: 320.412
#
# SATURN: 1982 January 0, 0h, TT - Ndays= -6575.50
#  Range (AU), RA, DEC: 9.798021 200.923976 -6.192950
#  Argument of PM 3: 263.595
#  N.Pole RA/DEC: 40.595 83.538
#  Sub-Earth Latitude (centric): 12.272
#  Calculated LCMIII: 327.742
#
# SATURN: 1983 January 0, 0h, TT - Ndays= -6210.50
#  Range (AU), RA, DEC: 10.096320 211.691833 -10.290278
#  Argument of PM 3: 283.369
#  N.Pole RA/DEC: 40.595 83.538
#  Sub-Earth Latitude (centric): 16.673
#  Calculated LCMIII: 335.237
#
# SATURN: 1984 January 0, 0h, TT - Ndays= -5845.50
#  Range (AU), RA, DEC: 10.364172 222.324215 -13.899531
#  Argument of PM 3: 303.144
#  N.Pole RA/DEC: 40.595 83.538
#  Sub-Earth Latitude (centric): 20.359
#  Calculated LCMIII: 342.820
#
# SATURN: 1985 January 0, 0h, TT - Ndays= -5479.50
#  Range (AU), RA, DEC: 10.581888 233.024035 -16.971214
#  Argument of PM 3: 53.712
#  N.Pole RA/DEC: 40.594 83.538
#  Sub-Earth Latitude (centric): 23.276
#  Calculated LCMIII: 81.209
#
# SATURN: 1986 January 0, 0h, TT - Ndays= -5114.50
#  Range (AU), RA, DEC: 10.769058 243.673579 -19.402711
#  Argument of PM 3: 73.486
#  N.Pole RA/DEC: 40.594 83.538
#  Sub-Earth Latitude (centric): 25.325
#  Calculated LCMIII: 88.912
#
# SATURN: 1987 January 0, 0h, TT - Ndays= -4749.50
#  Range (AU), RA, DEC: 10.907214 254.387391 -21.172253
#  Argument of PM 3: 93.261
#  N.Pole RA/DEC: 40.594 83.538
#  Sub-Earth Latitude (centric): 26.494
#  Calculated LCMIII: 96.768
#
# SATURN: 1988 January 0, 0h, TT - Ndays= -4384.50
#  Range (AU), RA, DEC: 10.993116 265.163557 -22.246993
#  Argument of PM 3: 113.035
#  N.Pole RA/DEC: 40.593 83.537
#  Sub-Earth Latitude (centric): 26.770
#  Calculated LCMIII: 104.879
#
# SATURN: 1989 January 0, 0h, TT - Ndays= -4018.50
#  Range (AU), RA, DEC: 11.024003 276.104489 -22.602952
#  Argument of PM 3: 223.603
#  N.Pole RA/DEC: 40.593 83.537
#  Sub-Earth Latitude (centric): 26.151
#  Calculated LCMIII: 204.018
#
# SATURN: 1990 January 0, 0h, TT - Ndays= -3653.50
#  Range (AU), RA, DEC: 11.004253 286.914914 -22.232660
#  Argument of PM 3: 243.378
#  N.Pole RA/DEC: 40.593 83.537
#  Sub-Earth Latitude (centric): 24.696
#  Calculated LCMIII: 212.928
#
# SATURN: 1991 January 0, 0h, TT - Ndays= -3288.50
#  Range (AU), RA, DEC: 10.930010 297.682044 -21.148677
#  Argument of PM 3: 263.152
#  N.Pole RA/DEC: 40.592 83.537
#  Sub-Earth Latitude (centric): 22.455
#  Calculated LCMIII: 222.345
#
# SATURN: 1992 January 0, 0h, TT - Ndays= -2923.50
#  Range (AU), RA, DEC: 10.802894 308.382127 -19.372300
#  Argument of PM 3: 282.926
#  N.Pole RA/DEC: 40.592 83.537
#  Sub-Earth Latitude (centric): 19.493
#  Calculated LCMIII: 232.267
#
# SATURN: 1993 January 0, 0h, TT - Ndays= -2557.50
#  Range (AU), RA, DEC: 10.635595 319.119324 -16.905611
#  Argument of PM 3: 33.495
#  N.Pole RA/DEC: 40.592 83.537
#  Sub-Earth Latitude (centric): 15.842
#  Calculated LCMIII: 333.288
#
# SATURN: 1994 January 0, 0h, TT - Ndays= -2192.50
#  Range (AU), RA, DEC: 10.414733 329.705073 -13.853450
#  Argument of PM 3: 53.269
#  N.Pole RA/DEC: 40.591 83.537
#  Sub-Earth Latitude (centric): 11.662
#  Calculated LCMIII: 344.007
#
# SATURN: 1995 January 0, 0h, TT - Ndays= -1827.50
#  Range (AU), RA, DEC: 10.153801 340.322900 -10.244672
#  Argument of PM 3: 73.043
#  N.Pole RA/DEC: 40.591 83.537
#  Sub-Earth Latitude (centric):  6.995
#  Calculated LCMIII: 354.916
#
# SATURN: 1996 January 0, 0h, TT - Ndays= -1462.50
#  Range (AU), RA, DEC: 9.860890 351.079533 -6.149321
#  Argument of PM 3: 92.818
#  N.Pole RA/DEC: 40.590 83.537
#  Sub-Earth Latitude (centric):  1.936
#  Calculated LCMIII:  5.806
#
# SATURN: 1997 January 0, 0h, TT - Ndays= -1096.50
#  Range (AU), RA, DEC: 9.562988 2.160022 -1.637346
#  Argument of PM 3: 203.386
#  N.Pole RA/DEC: 40.590 83.537
#  Sub-Earth Latitude (centric): -3.425
#  Calculated LCMIII: 107.098
#
# SATURN: 1998 January 0, 0h, TT - Ndays=  -731.50
#  Range (AU), RA, DEC: 9.240382 13.638384 3.111358
#  Argument of PM 3: 223.160
#  N.Pole RA/DEC: 40.590 83.537
#  Sub-Earth Latitude (centric): -8.866
#  Calculated LCMIII: 117.151
#
# SATURN: 1999 January 0, 0h, TT - Ndays=  -366.50
#  Range (AU), RA, DEC: 8.924057 25.781760 7.947353
#  Argument of PM 3: 242.935
#  N.Pole RA/DEC: 40.589 83.537
#  Sub-Earth Latitude (centric): -14.191
#  Calculated LCMIII: 126.280
#
# SATURN: 2000 January 0, 0h, TT - Ndays=    -1.50
#  Range (AU), RA, DEC: 8.631341 38.801146 12.620039
#  Argument of PM 3: 262.709
#  N.Pole RA/DEC: 40.589 83.537
#  Sub-Earth Latitude (centric): -19.080
#  Calculated LCMIII: 134.137
#
# SATURN: 2001 January 0, 0h, TT - Ndays=   364.50
#  Range (AU), RA, DEC: 8.392094 52.823134 16.789036
#  Argument of PM 3: 13.277
#  N.Pole RA/DEC: 40.589 83.537
#  Sub-Earth Latitude (centric): -23.100
#  Calculated LCMIII: 231.237
#
# SATURN: 2002 January 0, 0h, TT - Ndays=   729.50
#  Range (AU), RA, DEC: 8.198080 67.972352 20.065959
#  Argument of PM 3: 33.052
#  N.Pole RA/DEC: 40.588 83.537
#  Sub-Earth Latitude (centric): -25.773
#  Calculated LCMIII: 235.993
#
# SATURN: 2003 January 0, 0h, TT - Ndays=  1094.50
#  Range (AU), RA, DEC: 8.080391 84.046894 22.038258
#  Argument of PM 3: 52.826
#  N.Pole RA/DEC: 40.588 83.537
#  Sub-Earth Latitude (centric): -26.652
#  Calculated LCMIII: 239.477
#
# SATURN: 2004 January 0, 0h, TT - Ndays=  1459.50
#  Range (AU), RA, DEC: 8.050209 100.585047 22.407851
#  Argument of PM 3: 72.601
#  N.Pole RA/DEC: 40.588 83.537
#  Sub-Earth Latitude (centric): -25.519
#  Calculated LCMIII: 242.384
#
# SATURN: 2005 January 0, 0h, TT - Ndays=  1825.50
#  Range (AU), RA, DEC: 8.105852 116.872526 21.126852
#  Argument of PM 3: 183.169
#  N.Pole RA/DEC: 40.587 83.537
#  Sub-Earth Latitude (centric): -22.522
#  Calculated LCMIII: 336.396
#
# SATURN: 2006 January 0, 0h, TT - Ndays=  2190.50
#  Range (AU), RA, DEC: 8.246601 132.521344 18.368679
#  Argument of PM 3: 202.943
#  N.Pole RA/DEC: 40.587 83.537
#  Sub-Earth Latitude (centric): -18.030
#  Calculated LCMIII: 340.268
#
# SATURN: 2007 January 0, 0h, TT - Ndays=  2555.50
#  Range (AU), RA, DEC: 8.460008 147.118223 14.518927
#  Argument of PM 3: 222.718
#  N.Pole RA/DEC: 40.586 83.537
#  Sub-Earth Latitude (centric): -12.597
#  Calculated LCMIII: 345.080
#
# SATURN: 2008 January 0, 0h, TT - Ndays=  2920.50
#  Range (AU), RA, DEC: 8.728679 160.610128 10.001726
#  Argument of PM 3: 242.492
#  N.Pole RA/DEC: 40.586 83.537
#  Sub-Earth Latitude (centric): -6.725
#  Calculated LCMIII: 350.774
#
# SATURN: 2009 January 0, 0h, TT - Ndays=  3286.50
#  Range (AU), RA, DEC: 9.017648 173.127599 5.195005
#  Argument of PM 3: 353.060
#  N.Pole RA/DEC: 40.586 83.537
#  Sub-Earth Latitude (centric): -0.812
#  Calculated LCMIII: 88.041
#
# SATURN: 2010 January 0, 0h, TT - Ndays=  3651.50
#  Range (AU), RA, DEC: 9.339186 184.888849 0.371310
#  Argument of PM 3: 12.835
#  N.Pole RA/DEC: 40.585 83.537
#  Sub-Earth Latitude (centric):  4.875
#  Calculated LCMIII: 94.947
#
# SATURN: 2011 January 0, 0h, TT - Ndays=  4016.50
#  Range (AU), RA, DEC: 9.662117 196.091802 -4.250042
#  Argument of PM 3: 32.609
#  N.Pole RA/DEC: 40.585 83.537
#  Sub-Earth Latitude (centric): 10.125
#  Calculated LCMIII: 102.198
#
# SATURN: 2012 January 0, 0h, TT - Ndays=  4381.50
#  Range (AU), RA, DEC: 9.971874 206.932266 -8.524217
#  Argument of PM 3: 52.383
#  N.Pole RA/DEC: 40.585 83.537
#  Sub-Earth Latitude (centric): 14.801
#  Calculated LCMIII: 109.659
#
# SATURN: 2013 January 0, 0h, TT - Ndays=  4747.50
#  Range (AU), RA, DEC: 10.242264 217.651190 -12.370931
#  Argument of PM 3: 162.952
#  N.Pole RA/DEC: 40.584 83.536
#  Sub-Earth Latitude (centric): 18.826
#  Calculated LCMIII: 208.017
#
# SATURN: 2014 January 0, 0h, TT - Ndays=  5112.50
#  Range (AU), RA, DEC: 10.494445 228.233319 -15.669943
#  Argument of PM 3: 182.726
#  N.Pole RA/DEC: 40.584 83.536
#  Sub-Earth Latitude (centric): 22.074
#  Calculated LCMIII: 215.634
#
# SATURN: 2015 January 0, 0h, TT - Ndays=  5477.50
#  Range (AU), RA, DEC: 10.704992 238.826276 -18.379613
#  Argument of PM 3: 202.500
#  N.Pole RA/DEC: 40.584 83.536
#  Sub-Earth Latitude (centric): 24.505
#  Calculated LCMIII: 223.316
#
# SATURN: 2016 January 0, 0h, TT - Ndays=  5842.50
#  Range (AU), RA, DEC: 10.868411 249.479280 -20.451014
#  Argument of PM 3: 222.275
#  N.Pole RA/DEC: 40.583 83.536
#  Sub-Earth Latitude (centric): 26.074
#  Calculated LCMIII: 231.112
#
# SATURN: 2017 January 0, 0h, TT - Ndays=  6208.50
#  Range (AU), RA, DEC: 10.975524 260.328994 -21.853498
#  Argument of PM 3: 332.843
#  N.Pole RA/DEC: 40.583 83.536
#  Sub-Earth Latitude (centric): 26.757
#  Calculated LCMIII: 329.796
#
# SATURN: 2018 January 0, 0h, TT - Ndays=  6573.50
#  Range (AU), RA, DEC: 11.036845 271.117476 -22.535479
#  Argument of PM 3: 352.617
#  N.Pole RA/DEC: 40.583 83.536
#  Sub-Earth Latitude (centric): 26.546
#  Calculated LCMIII: 338.081
#
# SATURN: 2019 January 0, 0h, TT - Ndays=  6938.50
#  Range (AU), RA, DEC: 11.042913 281.923657 -22.498307
#  Argument of PM 3: 12.392
#  N.Pole RA/DEC: 40.582 83.536
#  Sub-Earth Latitude (centric): 25.474
#  Calculated LCMIII: 346.782
#
# SATURN: 2020 January 0, 0h, TT - Ndays=  7303.50
#  Range (AU), RA, DEC: 10.993035 292.706099 -21.743071
#  Argument of PM 3: 32.166
#  N.Pole RA/DEC: 40.582 83.536
#  Sub-Earth Latitude (centric): 23.590
#  Calculated LCMIII: 355.974
#
# SATURN: 2021 January 0, 0h, TT - Ndays=  7669.50
#  Range (AU), RA, DEC: 10.893764 303.548844 -20.260961
#  Argument of PM 3: 142.734
#  N.Pole RA/DEC: 40.581 83.536
#  Sub-Earth Latitude (centric): 20.918
#  Calculated LCMIII: 96.336
#
# SATURN: 2022 January 0, 0h, TT - Ndays=  8034.50
#  Range (AU), RA, DEC: 10.737375 314.195432 -18.122069
#  Argument of PM 3: 162.509
#  N.Pole RA/DEC: 40.581 83.536
#  Sub-Earth Latitude (centric): 17.597
#  Calculated LCMIII: 106.536
#
# SATURN: 2023 January 0, 0h, TT - Ndays=  8399.50
#  Range (AU), RA, DEC: 10.531238 324.789783 -15.348357
#  Argument of PM 3: 182.283
#  N.Pole RA/DEC: 40.581 83.536
#  Sub-Earth Latitude (centric): 13.672
#  Calculated LCMIII: 117.142
#
# SATURN: 2024 January 0, 0h, TT - Ndays=  8764.50
#  Range (AU), RA, DEC: 10.281299 335.381771 -11.990306
#  Argument of PM 3: 202.058
#  N.Pole RA/DEC: 40.580 83.536
#  Sub-Earth Latitude (centric):  9.220
#  Calculated LCMIII: 128.017
#
# SATURN: 2025 January 0, 0h, TT - Ndays=  9130.50
#  Range (AU), RA, DEC: 10.010341 346.126169 -8.080696
#  Argument of PM 3: 312.626
#  N.Pole RA/DEC: 40.580 83.536
#  Sub-Earth Latitude (centric):  4.294
#  Calculated LCMIII: 229.635
#
# SATURN: 2026 January 0, 0h, TT - Ndays=  9495.50
#  Range (AU), RA, DEC: 9.699085 356.997188 -3.765882
#  Argument of PM 3: 332.400
#  N.Pole RA/DEC: 40.580 83.536
#  Sub-Earth Latitude (centric): -0.923
#  Calculated LCMIII: 240.454
#
# SATURN: 2027 January 0, 0h, TT - Ndays=  9860.50
#  Range (AU), RA, DEC: 9.372844 8.241782 0.879124
#  Argument of PM 3: 352.175
#  N.Pole RA/DEC: 40.579 83.536
#  Sub-Earth Latitude (centric): -6.336
#  Calculated LCMIII: 250.840
#
# SATURN: 2028 January 0, 0h, TT - Ndays= 10225.50
#  Range (AU), RA, DEC: 9.046356 20.057337 5.703854
#  Argument of PM 3: 11.949
#  N.Pole RA/DEC: 40.579 83.536
#  Sub-Earth Latitude (centric): -11.752
#  Calculated LCMIII: 260.460
#
# SATURN: 2029 January 0, 0h, TT - Ndays= 10591.50
#  Range (AU), RA, DEC: 8.751641 32.649042 10.495379
#  Argument of PM 3: 122.517
#  N.Pole RA/DEC: 40.579 83.536
#  Sub-Earth Latitude (centric): -16.896
#  Calculated LCMIII: 359.686
#
# SATURN: 2030 January 0, 0h, TT - Ndays= 10956.50
#  Range (AU), RA, DEC: 8.475194 46.218540 14.949491
#  Argument of PM 3: 142.292
#  N.Pole RA/DEC: 40.578 83.536
#  Sub-Earth Latitude (centric): -21.381
#  Calculated LCMIII:  6.752

# %% [markdown]
# ## Uranus Calculation

# %%
# Note that the Archinal 2009 definitions are for 2000 Jan 1st 12:00 
# "Barycentric Dynamical Time (TDB)"

et1 = spice.str2et('2000-01-01TDB12:00')
nyrs=21

# Note that the Astronomical Almanac uses "TT" or "terrestrial time"
# which is the same as TDT "Terrestrial Dynamical Time"
for i in range(1980,2030,1):
    yr=i
    
    # Almanac gives positions at January 0, 0hr TT/TDT, which is the same as Dec 31T00:00
    dstring=str(yr)+'-12-31TDT00:00'
    #print(dstring)
    
    

    et2 = spice.str2et(dstring)
    days=(et2-et1)/(24.*60.*60.)

    [pos, ltime] = spice.spkpos( 'URANUS', et2, 'J2000','NONE', 'EARTH')
    [r, ra, dec ] = spice.recrad(pos)
    dist = spice.vnorm( pos )
    delta = spice.convrt( dist, 'KM', 'AU' )
    a=ra*r2d
    d=dec*r2d

    utc=spice.et2datetime(et2)
    print('')
    print('URANUS:',yr+1,'January 0, 0h, TT - Ndays=','{0:8.2f}'.format(days))
    print(' Range (AU), RA, DEC: {0:8.6f}'.format(delta), '{0:8.6f}'.format(a), '{0:8.6f}'.format(d))

# Calculate the argument of prime meridian for a single day

    w3=ura_w0_3 + days*ura_wt3
    w3=np.mod(w3,360.)

    print(' Argument of PM 3: {:6.3f}'.format(w3))

    
    #From IDL code planetlcm.pro
    #Be=asind(-sind(d1)*sind(d)-cosd(d1)*cosd(d)*cosd(a1-a))  

    # Tcent is the interval in Julian centuries from J2000
    Tcent=days/36525.
    a1=ura_a0+ura_arate*Tcent
    d1=ura_d0+ura_drate*Tcent
    
    print(' N.Pole RA/DEC: {:6.3f}'.format(a1),'{:6.3f}'.format(d1))

    
    sd1=np.sin(d1*d2r)
    sd=np.sin(d*d2r)
    cd1=np.cos(d1*d2r)
    cd=np.cos(d*d2r)
    ca1a=np.cos((a1-a)*d2r)
    sa1a=np.sin((a1-a)*d2r)

    arg=(-sd1*sd - cd1*cd*ca1a)
    Be=np.arcsin(arg)

    print(" Sub-Earth Latitude (centric):",'{:6.3f}'.format(Be*r2d))

    cBe=np.cos(Be)

    # Correction term for jovicentric longitude of sub-earth point
    # From IDL code planetlcm.pro
    #K=atan2d((-cosd(d1)*sind(d)+sind(d1)*cosd(d)*cosd(a1-a))/cosd(Be),(cosd(d)*sind(a1-a))/cosd(Be))

    arg1= (-cd1*sd+sd1*cd*ca1a)/cBe
    arg2= (cd*sa1a)/cBe

    #atan2d = double(atan(x1,x2)*57.2958), i.e.  the angle in degrees whose tangent is x2/x1.  

    K=np.arctan2(arg1,arg2)*r2d

    #print("Longitude Correction K:",K)

    # Argument of prime meridian at the time of observation andedated by light time.
    lcm3=K-(ura_w0_3+ura_wt3*(days-.0057755*delta))  # Note the change in sign as wt3<0
    lcm3=np.mod(lcm3,360.)

     
    print(" Calculated LCMIII:",'{:6.3f}'.format(lcm3))
# Out:
# URANUS: 1981 January 0, 0h, TT - Ndays= -6940.50
#  Range (AU), RA, DEC: 19.518720 236.452949 -19.638623
#  Argument of PM 3: 185.434
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -69.619
#  Calculated LCMIII: 133.726
#
# URANUS: 1982 January 0, 0h, TT - Ndays= -6575.50
#  Range (AU), RA, DEC: 19.634215 240.883317 -20.575486
#  Argument of PM 3: 142.000
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -73.471
#  Calculated LCMIII: 182.637
#
# URANUS: 1983 January 0, 0h, TT - Ndays= -6210.50
#  Range (AU), RA, DEC: 19.745329 245.325841 -21.391633
#  Argument of PM 3: 98.566
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -77.041
#  Calculated LCMIII: 234.717
#
# URANUS: 1984 January 0, 0h, TT - Ndays= -5845.50
#  Range (AU), RA, DEC: 19.851319 249.775777 -22.084068
#  Argument of PM 3: 55.132
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -80.069
#  Calculated LCMIII: 292.614
#
# URANUS: 1985 January 0, 0h, TT - Ndays= -5479.50
#  Range (AU), RA, DEC: 19.944752 254.288085 -22.656888
#  Argument of PM 3: 230.538
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -81.991
#  Calculated LCMIII: 141.288
#
# URANUS: 1986 January 0, 0h, TT - Ndays= -5114.50
#  Range (AU), RA, DEC: 20.040200 258.733580 -23.094547
#  Argument of PM 3: 187.105
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -81.967
#  Calculated LCMIII: 214.296
#
# URANUS: 1987 January 0, 0h, TT - Ndays= -4749.50
#  Range (AU), RA, DEC: 20.129526 263.164852 -23.404808
#  Argument of PM 3: 143.671
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -80.091
#  Calculated LCMIII: 281.017
#
# URANUS: 1988 January 0, 0h, TT - Ndays= -4384.50
#  Range (AU), RA, DEC: 20.212754 267.574743 -23.588479
#  Argument of PM 3: 100.237
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -77.183
#  Calculated LCMIII: 338.658
#
# URANUS: 1989 January 0, 0h, TT - Ndays= -4018.50
#  Range (AU), RA, DEC: 20.288195 272.022706 -23.646698
#  Argument of PM 3: 275.643
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -73.761
#  Calculated LCMIII: 171.928
#
# URANUS: 1990 January 0, 0h, TT - Ndays= -3653.50
#  Range (AU), RA, DEC: 20.361182 276.372889 -23.581376
#  Argument of PM 3: 232.209
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -70.179
#  Calculated LCMIII: 220.827
#
# URANUS: 1991 January 0, 0h, TT - Ndays= -3288.50
#  Range (AU), RA, DEC: 20.428110 280.685924 -23.396714
#  Argument of PM 3: 188.775
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -66.495
#  Calculated LCMIII: 268.018
#
# URANUS: 1992 January 0, 0h, TT - Ndays= -2923.50
#  Range (AU), RA, DEC: 20.488749 284.958197 -23.096184
#  Argument of PM 3: 145.341
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -62.760
#  Calculated LCMIII: 314.185
#
# URANUS: 1993 January 0, 0h, TT - Ndays= -2557.50
#  Range (AU), RA, DEC: 20.545237 289.249302 -22.676013
#  Argument of PM 3: 320.747
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -58.941
#  Calculated LCMIII: 140.887
#
# URANUS: 1994 January 0, 0h, TT - Ndays= -2192.50
#  Range (AU), RA, DEC: 20.592893 293.427401 -22.154425
#  Argument of PM 3: 277.313
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -55.166
#  Calculated LCMIII: 185.966
#
# URANUS: 1995 January 0, 0h, TT - Ndays= -1827.50
#  Range (AU), RA, DEC: 20.632725 297.554279 -21.530071
#  Argument of PM 3: 233.880
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -51.385
#  Calculated LCMIII: 230.753
#
# URANUS: 1996 January 0, 0h, TT - Ndays= -1462.50
#  Range (AU), RA, DEC: 20.664159 301.627715 -20.808079
#  Argument of PM 3: 190.446
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -47.603
#  Calculated LCMIII: 275.335
#
# URANUS: 1997 January 0, 0h, TT - Ndays= -1096.50
#  Range (AU), RA, DEC: 20.694091 305.702419 -19.981059
#  Argument of PM 3:  5.852
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -43.769
#  Calculated LCMIII: 100.925
#
# URANUS: 1998 January 0, 0h, TT - Ndays=  -731.50
#  Range (AU), RA, DEC: 20.709002 309.661726 -19.079461
#  Argument of PM 3: 322.418
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -39.994
#  Calculated LCMIII: 145.252
#
# URANUS: 1999 January 0, 0h, TT - Ndays=  -366.50
#  Range (AU), RA, DEC: 20.714821 313.564128 -18.097403
#  Argument of PM 3: 278.984
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -36.224
#  Calculated LCMIII: 189.504
#
# URANUS: 2000 January 0, 0h, TT - Ndays=    -1.50
#  Range (AU), RA, DEC: 20.712079 317.410118 -17.040840
#  Argument of PM 3: 235.550
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -32.460
#  Calculated LCMIII: 233.702
#
# URANUS: 2001 January 0, 0h, TT - Ndays=   364.50
#  Range (AU), RA, DEC: 20.712405 321.248984 -15.900534
#  Argument of PM 3: 50.956
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -28.654
#  Calculated LCMIII: 58.998
#
# URANUS: 2002 January 0, 0h, TT - Ndays=   729.50
#  Range (AU), RA, DEC: 20.695127 324.987084 -14.712160
#  Argument of PM 3:  7.522
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -24.901
#  Calculated LCMIII: 103.126
#
# URANUS: 2003 January 0, 0h, TT - Ndays=  1094.50
#  Range (AU), RA, DEC: 20.670979 328.679295 -13.465984
#  Argument of PM 3: 324.088
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -21.151
#  Calculated LCMIII: 147.235
#
# URANUS: 2004 January 0, 0h, TT - Ndays=  1459.50
#  Range (AU), RA, DEC: 20.640209 332.331628 -12.166728
#  Argument of PM 3: 280.655
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -17.399
#  Calculated LCMIII: 191.333
#
# URANUS: 2005 January 0, 0h, TT - Ndays=  1825.50
#  Range (AU), RA, DEC: 20.617145 335.986318 -10.804631
#  Argument of PM 3: 96.061
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -13.605
#  Calculated LCMIII: 16.552
#
# URANUS: 2006 January 0, 0h, TT - Ndays=  2190.50
#  Range (AU), RA, DEC: 20.574168 339.573898 -9.413881
#  Argument of PM 3: 52.627
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -9.846
#  Calculated LCMIII: 60.645
#
# URANUS: 2007 January 0, 0h, TT - Ndays=  2555.50
#  Range (AU), RA, DEC: 20.524571 343.140483 -7.983816
#  Argument of PM 3:  9.193
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -6.077
#  Calculated LCMIII: 104.747
#
# URANUS: 2008 January 0, 0h, TT - Ndays=  2920.50
#  Range (AU), RA, DEC: 20.468329 346.692203 -6.519142
#  Argument of PM 3: 325.759
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): -2.297
#  Calculated LCMIII: 148.863
#
# URANUS: 2009 January 0, 0h, TT - Ndays=  3286.50
#  Range (AU), RA, DEC: 20.421560 350.260410 -5.013186
#  Argument of PM 3: 141.165
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric):  1.524
#  Calculated LCMIII: 334.114
#
# URANUS: 2010 January 0, 0h, TT - Ndays=  3651.50
#  Range (AU), RA, DEC: 20.351867 353.798228 -3.494539
#  Argument of PM 3: 97.731
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric):  5.330
#  Calculated LCMIII: 18.271
#
# URANUS: 2011 January 0, 0h, TT - Ndays=  4016.50
#  Range (AU), RA, DEC: 20.275074 357.339194 -1.956179
#  Argument of PM 3: 54.297
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric):  9.150
#  Calculated LCMIII: 62.457
#
# URANUS: 2012 January 0, 0h, TT - Ndays=  4381.50
#  Range (AU), RA, DEC: 20.191513 0.889119 -0.403459
#  Argument of PM 3: 10.863
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 12.987
#  Calculated LCMIII: 106.677
#
# URANUS: 2013 January 0, 0h, TT - Ndays=  4747.50
#  Range (AU), RA, DEC: 20.118930 4.466787 1.164282
#  Argument of PM 3: 186.269
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 16.855
#  Calculated LCMIII: 292.048
#
# URANUS: 2014 January 0, 0h, TT - Ndays=  5112.50
#  Range (AU), RA, DEC: 20.023872 8.048825 2.727156
#  Argument of PM 3: 142.836
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 20.721
#  Calculated LCMIII: 336.347
#
# URANUS: 2015 January 0, 0h, TT - Ndays=  5477.50
#  Range (AU), RA, DEC: 19.924447 11.659409 4.287711
#  Argument of PM 3: 99.402
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 24.605
#  Calculated LCMIII: 20.693
#
# URANUS: 2016 January 0, 0h, TT - Ndays=  5842.50
#  Range (AU), RA, DEC: 19.821467 15.306097 5.840357
#  Argument of PM 3: 55.968
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 28.510
#  Calculated LCMIII: 65.093
#
# URANUS: 2017 January 0, 0h, TT - Ndays=  6208.50
#  Range (AU), RA, DEC: 19.732570 18.997719 7.380317
#  Argument of PM 3: 231.374
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 32.438
#  Calculated LCMIII: 250.670
#
# URANUS: 2018 January 0, 0h, TT - Ndays=  6573.50
#  Range (AU), RA, DEC: 19.624322 22.738197 8.898480
#  Argument of PM 3: 187.940
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 36.385
#  Calculated LCMIII: 295.214
#
# URANUS: 2019 January 0, 0h, TT - Ndays=  6938.50
#  Range (AU), RA, DEC: 19.514241 26.539753 10.390765
#  Argument of PM 3: 144.506
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 40.359
#  Calculated LCMIII: 339.856
#
# URANUS: 2020 January 0, 0h, TT - Ndays=  7303.50
#  Range (AU), RA, DEC: 19.402934 30.410572 11.850189
#  Argument of PM 3: 101.072
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 44.358
#  Calculated LCMIII: 24.622
#
# URANUS: 2021 January 0, 0h, TT - Ndays=  7669.50
#  Range (AU), RA, DEC: 19.305830 34.346070 13.265619
#  Argument of PM 3: 276.478
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 48.372
#  Calculated LCMIII: 210.664
#
# URANUS: 2022 January 0, 0h, TT - Ndays=  8034.50
#  Range (AU), RA, DEC: 19.191926 38.374343 14.635150
#  Argument of PM 3: 233.044
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 52.420
#  Calculated LCMIII: 255.811
#
# URANUS: 2023 January 0, 0h, TT - Ndays=  8399.50
#  Range (AU), RA, DEC: 19.077371 42.492356 15.947190
#  Argument of PM 3: 189.611
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 56.488
#  Calculated LCMIII: 301.257
#
# URANUS: 2024 January 0, 0h, TT - Ndays=  8764.50
#  Range (AU), RA, DEC: 18.962251 46.704035 17.191880
#  Argument of PM 3: 146.177
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 60.566
#  Calculated LCMIII: 347.131
#
# URANUS: 2025 January 0, 0h, TT - Ndays=  9130.50
#  Range (AU), RA, DEC: 18.859221 50.985423 18.352633
#  Argument of PM 3: 321.583
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 64.616
#  Calculated LCMIII: 174.749
#
# URANUS: 2026 January 0, 0h, TT - Ndays=  9495.50
#  Range (AU), RA, DEC: 18.743824 55.386391 19.430955
#  Argument of PM 3: 278.149
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 68.657
#  Calculated LCMIII: 222.251
#
# URANUS: 2027 January 0, 0h, TT - Ndays=  9860.50
#  Range (AU), RA, DEC: 18.630146 59.884347 20.410382
#  Argument of PM 3: 234.715
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 72.614
#  Calculated LCMIII: 271.424
#
# URANUS: 2028 January 0, 0h, TT - Ndays= 10225.50
#  Range (AU), RA, DEC: 18.519421 64.477426 21.280333
#  Argument of PM 3: 191.281
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 76.376
#  Calculated LCMIII: 323.631
#
# URANUS: 2029 January 0, 0h, TT - Ndays= 10591.50
#  Range (AU), RA, DEC: 18.420758 69.124790 22.025678
#  Argument of PM 3:  6.687
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 79.655
#  Calculated LCMIII: 162.683
#
# URANUS: 2030 January 0, 0h, TT - Ndays= 10956.50
#  Range (AU), RA, DEC: 18.317716 73.895759 22.647215
#  Argument of PM 3: 323.253
#  N.Pole RA/DEC: 257.311 -15.175
#  Sub-Earth Latitude (centric): 81.860
#  Calculated LCMIII: 230.878

# %% [markdown]
# ## Calculation for Neptune

# %%
# Note that the Archinal 2009 definitions are for 2000 Jan 1st 12:00 
# "Barycentric Dynamical Time (TDB)"

et1 = spice.str2et('2000-01-01TDB12:00')
nyrs=21

# Note that the Astronomical Almanac uses "TT" or "terrestrial time"
# which is the same as TDT "Terrestrial Dynamical Time"
for i in range(1980,2030,1):
    yr=i
    
    # Almanac gives positions at January 0, 0hr TT/TDT, which is the same as Dec 31T00:00
    dstring=str(yr)+'-12-31TDT00:00'
    #print(dstring)
    
    

    et2 = spice.str2et(dstring)
    days=(et2-et1)/(24.*60.*60.)

    [pos, ltime] = spice.spkpos( 'NEPTUNE', et2, 'J2000','NONE', 'EARTH')
    [r, ra, dec ] = spice.recrad(pos)
    dist = spice.vnorm( pos )
    delta = spice.convrt( dist, 'KM', 'AU' )
    a=ra*r2d
    d=dec*r2d

    utc=spice.et2datetime(et2)
    print('')
    print('NEPTUNE:',yr+1,'January 0, 0h, TT - Ndays=','{0:8.2f}'.format(days))
    print(' Range (AU), RA, DEC: {0:8.6f}'.format(delta), '{0:8.6f}'.format(a), '{0:8.6f}'.format(d))

# Calculate the argument of prime meridian for a single day

    w3=nep_w0_3 + days*nep_wt3
    w3=np.mod(w3,360.)

    print(' Argument of PM 3: {:6.3f}'.format(w3))

    
    #From IDL code planetlcm.pro
    #Be=asind(-sind(d1)*sind(d)-cosd(d1)*cosd(d)*cosd(a1-a))  

    # Tcent is the interval in Julian centuries from J2000
    Tcent=days/36525.
    a1=nep_a0+nep_arate*Tcent
    d1=nep_d0+nep_drate*Tcent
    
    print(' N.Pole RA/DEC: {:6.3f}'.format(a1),'{:6.3f}'.format(d1))

    
    sd1=np.sin(d1*d2r)
    sd=np.sin(d*d2r)
    cd1=np.cos(d1*d2r)
    cd=np.cos(d*d2r)
    ca1a=np.cos((a1-a)*d2r)
    sa1a=np.sin((a1-a)*d2r)

    arg=(-sd1*sd - cd1*cd*ca1a)
    Be=np.arcsin(arg)

    print(" Sub-Earth Latitude (centric):",'{:6.3f}'.format(Be*r2d))

    cBe=np.cos(Be)

    # Correction term for jovicentric longitude of sub-earth point
    # From IDL code planetlcm.pro
    #K=atan2d((-cosd(d1)*sind(d)+sind(d1)*cosd(d)*cosd(a1-a))/cosd(Be),(cosd(d)*sind(a1-a))/cosd(Be))

    arg1= (-cd1*sd+sd1*cd*ca1a)/cBe
    arg2= (cd*sa1a)/cBe

    #atan2d = double(atan(x1,x2)*57.2958), i.e.  the angle in degrees whose tangent is x2/x1.  

    K=np.arctan2(arg1,arg2)*r2d

    #print("Longitude Correction K:",K)

    # Argument of prime meridian at the time of observation andedated by light time.
    lcm3=nep_w0_3+nep_wt3*(days-.0057755*delta)-K
    lcm3=np.mod(lcm3,360.)

     
    print(" Calculated LCMIII:",'{:6.3f}'.format(lcm3))
# Out:
# NEPTUNE: 1981 January 0, 0h, TT - Ndays= -6940.50
#  Range (AU), RA, DEC: 31.219080 262.764985 -21.974910
#  Argument of PM 3: 13.870
#  N.Pole RA/DEC: 299.365 43.497
#  Sub-Earth Latitude (centric): -16.409
#  Calculated LCMIII: 222.366
#
# NEPTUNE: 1982 January 0, 0h, TT - Ndays= -6575.50
#  Range (AU), RA, DEC: 31.226635 265.007142 -22.106871
#  Argument of PM 3: 288.059
#  N.Pole RA/DEC: 299.365 43.492
#  Sub-Earth Latitude (centric): -17.209
#  Calculated LCMIII: 134.523
#
# NEPTUNE: 1983 January 0, 0h, TT - Ndays= -6210.50
#  Range (AU), RA, DEC: 31.231626 267.254869 -22.208274
#  Argument of PM 3: 202.249
#  N.Pole RA/DEC: 299.364 43.487
#  Sub-Earth Latitude (centric): -17.990
#  Calculated LCMIII: 46.668
#
# NEPTUNE: 1984 January 0, 0h, TT - Ndays= -5845.50
#  Range (AU), RA, DEC: 31.233773 269.507069 -22.278840
#  Argument of PM 3: 116.439
#  N.Pole RA/DEC: 299.364 43.482
#  Sub-Earth Latitude (centric): -18.750
#  Calculated LCMIII: 318.804
#
# NEPTUNE: 1985 January 0, 0h, TT - Ndays= -5479.50
#  Range (AU), RA, DEC: 31.230413 271.802366 -22.317936
#  Argument of PM 3: 206.942
#  N.Pole RA/DEC: 299.364 43.476
#  Sub-Earth Latitude (centric): -19.501
#  Calculated LCMIII: 47.213
#
# NEPTUNE: 1986 January 0, 0h, TT - Ndays= -5114.50
#  Range (AU), RA, DEC: 31.227023 274.057704 -22.325699
#  Argument of PM 3: 121.132
#  N.Pole RA/DEC: 299.364 43.471
#  Sub-Earth Latitude (centric): -20.215
#  Calculated LCMIII: 319.328
#
# NEPTUNE: 1987 January 0, 0h, TT - Ndays= -4749.50
#  Range (AU), RA, DEC: 31.220852 276.311740 -22.302324
#  Argument of PM 3: 35.322
#  N.Pole RA/DEC: 299.363 43.466
#  Sub-Earth Latitude (centric): -20.904
#  Calculated LCMIII: 231.433
#
# NEPTUNE: 1988 January 0, 0h, TT - Ndays= -4384.50
#  Range (AU), RA, DEC: 31.212393 278.562971 -22.247904
#  Argument of PM 3: 309.512
#  N.Pole RA/DEC: 299.363 43.461
#  Sub-Earth Latitude (centric): -21.567
#  Calculated LCMIII: 143.528
#
# NEPTUNE: 1989 January 0, 0h, TT - Ndays= -4018.50
#  Range (AU), RA, DEC: 31.202734 280.851405 -22.159989
#  Argument of PM 3: 40.014
#  N.Pole RA/DEC: 299.363 43.456
#  Sub-Earth Latitude (centric): -22.214
#  Calculated LCMIII: 231.883
#
# NEPTUNE: 1990 January 0, 0h, TT - Ndays= -3653.50
#  Range (AU), RA, DEC: 31.192596 283.095533 -22.043522
#  Argument of PM 3: 314.204
#  N.Pole RA/DEC: 299.363 43.451
#  Sub-Earth Latitude (centric): -22.820
#  Calculated LCMIII: 143.947
#
# NEPTUNE: 1991 January 0, 0h, TT - Ndays= -3288.50
#  Range (AU), RA, DEC: 31.181576 285.336484 -21.896541
#  Argument of PM 3: 228.394
#  N.Pole RA/DEC: 299.362 43.446
#  Sub-Earth Latitude (centric): -23.398
#  Calculated LCMIII: 55.993
#
# NEPTUNE: 1992 January 0, 0h, TT - Ndays= -2923.50
#  Range (AU), RA, DEC: 31.169710 287.574784 -21.719168
#  Argument of PM 3: 142.584
#  N.Pole RA/DEC: 299.362 43.441
#  Sub-Earth Latitude (centric): -23.945
#  Calculated LCMIII: 328.021
#
# NEPTUNE: 1993 January 0, 0h, TT - Ndays= -2557.50
#  Range (AU), RA, DEC: 31.159326 289.850402 -21.506682
#  Argument of PM 3: 233.087
#  N.Pole RA/DEC: 299.362 43.436
#  Sub-Earth Latitude (centric): -24.472
#  Calculated LCMIII: 56.296
#
# NEPTUNE: 1994 January 0, 0h, TT - Ndays= -2192.50
#  Range (AU), RA, DEC: 31.145218 292.082481 -21.268510
#  Argument of PM 3: 147.277
#  N.Pole RA/DEC: 299.362 43.431
#  Sub-Earth Latitude (centric): -24.956
#  Calculated LCMIII: 328.288
#
# NEPTUNE: 1995 January 0, 0h, TT - Ndays= -1827.50
#  Range (AU), RA, DEC: 31.129034 294.310789 -21.000556
#  Argument of PM 3: 61.466
#  N.Pole RA/DEC: 299.361 43.425
#  Sub-Earth Latitude (centric): -25.407
#  Calculated LCMIII: 240.265
#
# NEPTUNE: 1996 January 0, 0h, TT - Ndays= -1462.50
#  Range (AU), RA, DEC: 31.110247 296.534397 -20.703216
#  Argument of PM 3: 335.656
#  N.Pole RA/DEC: 299.361 43.420
#  Sub-Earth Latitude (centric): -25.824
#  Calculated LCMIII: 152.231
#
# NEPTUNE: 1997 January 0, 0h, TT - Ndays= -1096.50
#  Range (AU), RA, DEC: 31.093889 298.790123 -20.370251
#  Argument of PM 3: 66.159
#  N.Pole RA/DEC: 299.361 43.415
#  Sub-Earth Latitude (centric): -26.212
#  Calculated LCMIII: 240.443
#
# NEPTUNE: 1998 January 0, 0h, TT - Ndays=  -731.50
#  Range (AU), RA, DEC: 31.070012 300.999379 -20.015381
#  Argument of PM 3: 340.349
#  N.Pole RA/DEC: 299.361 43.410
#  Sub-Earth Latitude (centric): -26.557
#  Calculated LCMIII: 152.389
#
# NEPTUNE: 1999 January 0, 0h, TT - Ndays=  -366.50
#  Range (AU), RA, DEC: 31.043193 303.199402 -19.633074
#  Argument of PM 3: 254.539
#  N.Pole RA/DEC: 299.360 43.405
#  Sub-Earth Latitude (centric): -26.863
#  Calculated LCMIII: 64.330
#
# NEPTUNE: 2000 January 0, 0h, TT - Ndays=    -1.50
#  Range (AU), RA, DEC: 31.014120 305.388880 -19.224138
#  Argument of PM 3: 168.729
#  N.Pole RA/DEC: 299.360 43.400
#  Sub-Earth Latitude (centric): -27.131
#  Calculated LCMIII: 336.265
#
# NEPTUNE: 2001 January 0, 0h, TT - Ndays=   364.50
#  Range (AU), RA, DEC: 30.991092 307.603008 -18.781158
#  Argument of PM 3: 259.231
#  N.Pole RA/DEC: 299.360 43.395
#  Sub-Earth Latitude (centric): -27.364
#  Calculated LCMIII: 64.445
#
# NEPTUNE: 2002 January 0, 0h, TT - Ndays=   729.50
#  Range (AU), RA, DEC: 30.960136 309.769611 -18.320964
#  Argument of PM 3: 173.421
#  N.Pole RA/DEC: 299.359 43.390
#  Sub-Earth Latitude (centric): -27.553
#  Calculated LCMIII: 336.367
#
# NEPTUNE: 2003 January 0, 0h, TT - Ndays=  1094.50
#  Range (AU), RA, DEC: 30.928763 311.926113 -17.836159
#  Argument of PM 3: 87.611
#  N.Pole RA/DEC: 299.359 43.385
#  Sub-Earth Latitude (centric): -27.701
#  Calculated LCMIII: 248.281
#
# NEPTUNE: 2004 January 0, 0h, TT - Ndays=  1459.50
#  Range (AU), RA, DEC: 30.897020 314.073662 -17.327156
#  Argument of PM 3:  1.801
#  N.Pole RA/DEC: 299.359 43.380
#  Sub-Earth Latitude (centric): -27.809
#  Calculated LCMIII: 160.188
#
# NEPTUNE: 2005 January 0, 0h, TT - Ndays=  1825.50
#  Range (AU), RA, DEC: 30.874693 316.245588 -16.785245
#  Argument of PM 3: 92.304
#  N.Pole RA/DEC: 299.359 43.375
#  Sub-Earth Latitude (centric): -27.877
#  Calculated LCMIII: 248.333
#
# NEPTUNE: 2006 January 0, 0h, TT - Ndays=  2190.50
#  Range (AU), RA, DEC: 30.842430 318.376412 -16.229258
#  Argument of PM 3:  6.494
#  N.Pole RA/DEC: 299.358 43.369
#  Sub-Earth Latitude (centric): -27.902
#  Calculated LCMIII: 160.226
#
# NEPTUNE: 2007 January 0, 0h, TT - Ndays=  2555.50
#  Range (AU), RA, DEC: 30.808964 320.500287 -15.650662
#  Argument of PM 3: 280.684
#  N.Pole RA/DEC: 299.358 43.364
#  Sub-Earth Latitude (centric): -27.885
#  Calculated LCMIII: 72.117
#
# NEPTUNE: 2008 January 0, 0h, TT - Ndays=  2920.50
#  Range (AU), RA, DEC: 30.773994 322.617240 -15.050241
#  Argument of PM 3: 194.874
#  N.Pole RA/DEC: 299.358 43.359
#  Sub-Earth Latitude (centric): -27.826
#  Calculated LCMIII: 344.008
#
# NEPTUNE: 2009 January 0, 0h, TT - Ndays=  3286.50
#  Range (AU), RA, DEC: 30.748971 324.756107 -14.419218
#  Argument of PM 3: 285.376
#  N.Pole RA/DEC: 299.358 43.354
#  Sub-Earth Latitude (centric): -27.723
#  Calculated LCMIII: 72.145
#
# NEPTUNE: 2010 January 0, 0h, TT - Ndays=  3651.50
#  Range (AU), RA, DEC: 30.710248 326.857418 -13.777820
#  Argument of PM 3: 199.566
#  N.Pole RA/DEC: 299.357 43.349
#  Sub-Earth Latitude (centric): -27.580
#  Calculated LCMIII: 344.047
#
# NEPTUNE: 2011 January 0, 0h, TT - Ndays=  4016.50
#  Range (AU), RA, DEC: 30.669179 328.950277 -13.117709
#  Argument of PM 3: 113.756
#  N.Pole RA/DEC: 299.357 43.344
#  Sub-Earth Latitude (centric): -27.394
#  Calculated LCMIII: 255.960
#
# NEPTUNE: 2012 January 0, 0h, TT - Ndays=  4381.50
#  Range (AU), RA, DEC: 30.626082 331.034186 -12.440043
#  Argument of PM 3: 27.946
#  N.Pole RA/DEC: 299.357 43.339
#  Sub-Earth Latitude (centric): -27.166
#  Calculated LCMIII: 167.885
#
# NEPTUNE: 2013 January 0, 0h, TT - Ndays=  4747.50
#  Range (AU), RA, DEC: 30.595171 333.133689 -11.736700
#  Argument of PM 3: 118.449
#  N.Pole RA/DEC: 299.357 43.334
#  Sub-Earth Latitude (centric): -26.895
#  Calculated LCMIII: 256.065
#
# NEPTUNE: 2014 January 0, 0h, TT - Ndays=  5112.50
#  Range (AU), RA, DEC: 30.550411 335.198103 -11.027570
#  Argument of PM 3: 32.639
#  N.Pole RA/DEC: 299.356 43.329
#  Sub-Earth Latitude (centric): -26.586
#  Calculated LCMIII: 168.017
#
# NEPTUNE: 2015 January 0, 0h, TT - Ndays=  5477.50
#  Range (AU), RA, DEC: 30.505508 337.255048 -10.303728
#  Argument of PM 3: 306.828
#  N.Pole RA/DEC: 299.356 43.324
#  Sub-Earth Latitude (centric): -26.237
#  Calculated LCMIII: 79.979
#
# NEPTUNE: 2016 January 0, 0h, TT - Ndays=  5842.50
#  Range (AU), RA, DEC: 30.460817 339.305729 -9.565839
#  Argument of PM 3: 221.018
#  N.Pole RA/DEC: 299.356 43.318
#  Sub-Earth Latitude (centric): -25.848
#  Calculated LCMIII: 351.952
#
# NEPTUNE: 2017 January 0, 0h, TT - Ndays=  6208.50
#  Range (AU), RA, DEC: 30.431570 341.372317 -8.805880
#  Argument of PM 3: 311.521
#  N.Pole RA/DEC: 299.356 43.313
#  Sub-Earth Latitude (centric): -25.416
#  Calculated LCMIII: 80.177
#
# NEPTUNE: 2018 January 0, 0h, TT - Ndays=  6573.50
#  Range (AU), RA, DEC: 30.387721 343.413816 -8.041921
#  Argument of PM 3: 225.711
#  N.Pole RA/DEC: 299.355 43.308
#  Sub-Earth Latitude (centric): -24.950
#  Calculated LCMIII: 352.172
#
# NEPTUNE: 2019 January 0, 0h, TT - Ndays=  6938.50
#  Range (AU), RA, DEC: 30.343713 345.453126 -7.265809
#  Argument of PM 3: 139.901
#  N.Pole RA/DEC: 299.355 43.303
#  Sub-Earth Latitude (centric): -24.446
#  Calculated LCMIII: 264.179
#
# NEPTUNE: 2020 January 0, 0h, TT - Ndays=  7303.50
#  Range (AU), RA, DEC: 30.299304 347.491494 -6.478268
#  Argument of PM 3: 54.091
#  N.Pole RA/DEC: 299.355 43.298
#  Sub-Earth Latitude (centric): -23.905
#  Calculated LCMIII: 176.200
#
# NEPTUNE: 2021 January 0, 0h, TT - Ndays=  7669.50
#  Range (AU), RA, DEC: 30.270152 349.545813 -5.672863
#  Argument of PM 3: 144.593
#  N.Pole RA/DEC: 299.354 43.293
#  Sub-Earth Latitude (centric): -23.324
#  Calculated LCMIII: 264.481
#
# NEPTUNE: 2022 January 0, 0h, TT - Ndays=  8034.50
#  Range (AU), RA, DEC: 30.223615 351.582327 -4.866007
#  Argument of PM 3: 58.783
#  N.Pole RA/DEC: 299.354 43.288
#  Sub-Earth Latitude (centric): -22.712
#  Calculated LCMIII: 176.538
#
# NEPTUNE: 2023 January 0, 0h, TT - Ndays=  8399.50
#  Range (AU), RA, DEC: 30.175469 353.618759 -4.051132
#  Argument of PM 3: 332.973
#  N.Pole RA/DEC: 299.354 43.283
#  Sub-Earth Latitude (centric): -22.066
#  Calculated LCMIII: 88.615
#
# NEPTUNE: 2024 January 0, 0h, TT - Ndays=  8764.50
#  Range (AU), RA, DEC: 30.125727 355.654514 -3.229826
#  Argument of PM 3: 247.163
#  N.Pole RA/DEC: 299.354 43.278
#  Sub-Earth Latitude (centric): -21.388
#  Calculated LCMIII:  0.714
#
# NEPTUNE: 2025 January 0, 0h, TT - Ndays=  9130.50
#  Range (AU), RA, DEC: 30.091889 357.700948 -2.397922
#  Argument of PM 3: 337.666
#  N.Pole RA/DEC: 299.353 43.273
#  Sub-Earth Latitude (centric): -20.675
#  Calculated LCMIII: 89.083
#
# NEPTUNE: 2026 January 0, 0h, TT - Ndays=  9495.50
#  Range (AU), RA, DEC: 30.040829 359.734065 -1.568414
#  Argument of PM 3: 251.856
#  N.Pole RA/DEC: 299.353 43.268
#  Sub-Earth Latitude (centric): -19.937
#  Calculated LCMIII:  1.226
#
# NEPTUNE: 2027 January 0, 0h, TT - Ndays=  9860.50
#  Range (AU), RA, DEC: 29.989955 1.767694 -0.736176
#  Argument of PM 3: 166.046
#  N.Pole RA/DEC: 299.353 43.262
#  Sub-Earth Latitude (centric): -19.171
#  Calculated LCMIII: 273.387
#
# NEPTUNE: 2028 January 0, 0h, TT - Ndays= 10225.50
#  Range (AU), RA, DEC: 29.939939 3.803280 0.098044
#  Argument of PM 3: 80.235
#  N.Pole RA/DEC: 299.353 43.257
#  Sub-Earth Latitude (centric): -18.377
#  Calculated LCMIII: 185.564
#
# NEPTUNE: 2029 January 0, 0h, TT - Ndays= 10591.50
#  Range (AU), RA, DEC: 29.908324 5.849574 0.937391
#  Argument of PM 3: 170.738
#  N.Pole RA/DEC: 299.352 43.252
#  Sub-Earth Latitude (centric): -17.556
#  Calculated LCMIII: 274.005
#
# NEPTUNE: 2030 January 0, 0h, TT - Ndays= 10956.50
#  Range (AU), RA, DEC: 29.860481 7.892645 1.772815
#  Argument of PM 3: 84.928
#  N.Pole RA/DEC: 299.352 43.247
#  Sub-Earth Latitude (centric): -16.711
#  Calculated LCMIII: 186.208
